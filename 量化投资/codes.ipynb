# %%
import pandas as pd
import os
import datetime
import warnings
index_1 = 0
index_2 = 0
df_list = pd.read_excel('/Users/liuhuanshuo/Desktop/作业/量化/stocks_list.xlsx')

# %%
df = pd.DataFrame(columns = ['沪A股票代码','日期','市盈率'])

# %%
#选出20160401日股票
#path = '/Users/liuhuanshuo/desktop/作业/单佳雷数据/沪A股票原始数据/'
for file in df_list['股票代码']:
    excel_path = os.path.join('/Users','liuhuanshuo','desktop','作业','量化','单佳雷数据','沪A股票原始数据/') + file + '.xls'
    df_one = pd.read_excel(excel_path)
    df_one = df_one.loc[:,['代码','日期','市盈率']]
    num_row = len(df_one['代码'])
    for i in range(0,num_row):
        if df_one.iloc[i,1] == datetime.datetime(2016,4,1) and df_one.iloc[i,2] > 0:
            df.loc[index_1] = [df_one.iloc[i,0],df_one.iloc[i,1],df_one.iloc[i,2]]
            index_1 += 1
            break
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ...

# %%
#市盈率排序
df_sort = df.sort_values(by='市盈率')
index_2 = 0
df_50 = pd.DataFrame(columns = ['沪A股票代码','日期','市盈率'])
for j in range(50):
    df_50.loc[index_2] = [df_sort.iloc[j,0],df_sort.iloc[j,1],df_sort.iloc[j,2]]
    index_2 += 1
    
df_50
# Out:
#        沪A股票代码         日期      市盈率
# 0   601939.SH 2016-04-01   5.3039
# 1   601398.SH 2016-04-01   5.5300
# 2   601288.SH 2016-04-01   5.7555
# 3   600015.SH 2016-04-01   5.7890
# 4   601988.SH 2016-04-01   5.8759
# 5   601166.SH 2016-04-01   5.9236
# 6   601818.SH 2016-04-01   5.9756
# 7   601328.SH 2016-04-01   6.2846
# 8   600894.SH 2016-04-01   6.4875
# 9   601668.SH 2016-04-01   6.6304
# 10  600000.SH 2016-04-01   7.0605
# 11  600036.SH 2016-04-01   7.1119
# 12  601998.SH 2016-04-01   7.2407
# 13  600027.SH 2016-04-01   7.2557
# 14  600185.SH 2016-04-01   7.2992
# 15  600016.SH 2016-04-01   7.3112
# 16  600104.SH 2016-04-01   7.5382
# 17  601169.SH 2016-04-01   7.5481
# 18  600177.SH 2016-04-01   7.6606
# 19  601009.SH 2016-04-01   7.7699
# 20  600048.SH 2016-04-01   8.1192
# 21  601006.SH 2016-04-01   8.1811
# 22  600889.SH 2016-04-01   8.3428
# 23  600886.SH 2016-04-01   8.5896
# 24  600578.SH 2016-04-01   8.6344
# 25  600011.SH 2016-04-01   8.8428
# ...

# %%
df_date = pd.read_excel('/Users/liuhuanshuo/Desktop/作业/量化/20160401至20160601的日期.xlsx')
df_alldaysprofit = pd.DataFrame(columns = ['日期','代码','买入日期','买入价','当日收盘价','该股票当日盈亏'])

# %%
flag = 0
index_3 = 0

# %%
for file in df_50['沪A股票代码']:
    excel_path = os.path.join('/Users','liuhuanshuo','desktop','作业','量化','单佳雷数据','沪A股票原始数据/') + file + '.xls'
    df_oneof50 = pd.read_excel(excel_path)
    warnings.filterwarnings("ignore")
    df_oneof50 = df_oneof50.loc[:,['代码','日期','开盘价(元)','收盘价(元)']]
    buy_date = datetime.datetime(2016,4,1)
    buy_price = df_oneof50[df_oneof50['日期'] == buy_date].iloc[0,2]
    
    for i in range(len(df_date)):
        for j in range(len(df_oneof50)):
            if df_oneof50.iloc[j,1] == df_date.iloc[i,0]:
                date = df_date.iloc[i,0]
                close_price = df_oneof50.iloc[j,3]
                profit = 100 * (close_price - buy_price)
                df_alldaysprofit.loc[index_3] = [date, df_oneof50.iloc[j,0],buy_date,buy_price,close_price,profit]
                index_3 += 1
                break
df_alldaysprofit
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ...

# %%
index_4 = 0
index_5 = 0
count = 0 #持仓股票个数
profit_today = 0 #当日组合盈亏
profit_accumulate = 0 #组合累计盈亏

# %%
df_last = pd.DataFrame(columns = ['日期','当日持仓股票个数','当日组合盈亏','当日组合累计收益'])
df_ProfitOfOneDay = pd.DataFrame(columns = ['日期','当日持仓股票个数','当日组合盈亏'])

# %%
for i in range(len(df_date)):
    for j in range(len(df_alldaysprofit)):
        if df_date.iloc[i,0] == df_alldaysprofit.iloc[j,0]:
            count += 1
            profit_today = profit_today + df_alldaysprofit.iloc[j,5]
    df_ProfitOfOneDay.loc[index_4] = [df_date.iloc[i,0], count, profit_today]
    index_4 += 1
    count = 0

# %%
profit_accumulate = df_ProfitOfOneDay.iloc[0,2]
df_last.loc[index_5] = [df_ProfitOfOneDay.iloc[0,0],df_ProfitOfOneDay.iloc[0,1],df_ProfitOfOneDay.iloc[0,2],profit_accumulate]
index_5 += 1

# %%
for k in range(1,len(df_ProfitOfOneDay)):
    profit_accumulate = profit_accumulate + df_ProfitOfOneDay.iloc[k,2]
    df_last.loc[index_5] = [df_ProfitOfOneDay.iloc[k,0],df_ProfitOfOneDay.iloc[k,1],df_ProfitOfOneDay.iloc[k,2],profit_accumulate]
    index_5 += 1
df_last
# Out:
#            日期 当日持仓股票个数    当日组合盈亏   当日组合累计收益
# 0  2016-04-01       50    236.56     236.56
# 1  2016-04-05       50   1099.16    1335.72
# 2  2016-04-06       50   1802.27    3137.99
# 3  2016-04-07       50   1734.35    4872.34
# 4  2016-04-08       50   1096.88    5969.22
# 5  2016-04-11       50   1316.88    7286.10
# 6  2016-04-12       50   1323.85    8609.95
# 7  2016-04-13       50   2247.09   10857.04
# 8  2016-04-14       50   3444.19   14301.23
# 9  2016-04-15       50   4637.91   18939.14
# 10 2016-04-18       50   4893.83   23832.97
# 11 2016-04-19       50   5403.86   29236.83
# 12 2016-04-20       50   5184.37   34421.20
# 13 2016-04-21       50   4532.87   38954.07
# 14 2016-04-22       50   4137.67   43091.74
# 15 2016-04-25       50   3395.50   46487.24
# 16 2016-04-26       50   2975.66   49462.90
# 17 2016-04-27       50   2249.53   51712.43
# 18 2016-04-28       50   1313.03   53025.46
# 19 2016-04-29       50    170.31   53195.77
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
myfont = fm.FontProperties(fname = '/Library/Fonts/Arial Unicode.ttf')
# %matplotlib inline
x = df_last.loc[:,['当日组合盈亏']]
y = df_last.loc[:,['当日组合累计收益']]
plt.style.use('ggplot')
line_up, = plt.plot(x, label=u'当日组合盈亏')
line_down, = plt.plot(y, label=u'当日组合累计收益')
plt.legend(handles=[line_up, line_down],prop = myfont)
plt.xlabel('股票个数',fontproperties = myfont)
plt.ylabel('收益',fontproperties = myfont)
plt.title('50只股票收益组合策略收益图',fontproperties = myfont)
# Out:
# Text(0.5,1,'50只股票收益组合策略收益图')

# %%
line_up, = plt.plot(x, label=u'当日组合盈亏')
line_down, = plt.plot(y, label=u'当日组合累计收益')
plt.legend(handles=[line_up, line_down],prop = myfont)
plt.show()
