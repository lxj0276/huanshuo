# %%
import tushare as ts
import pandas as pd
from pandas.core.frame import DataFrame

# %%
a = ts.get_hs300s()
# Out:
# http://www.csindex.com.cn/uploads/file/autofile/closeweight/000300closeweight.xls

# %%
qq = []

# %%
m = 1
for i in a.iloc[:,1]:
    s = ts.get_hist_data(i,start='2016-01-01',end='2017-01-01')
    try:
        s.insert(0,'code',i)
    except:
        pass
    print('正在保存第{0}个数据，代码是{1}'.format(m,i))
    try:
        n = str(i) + '.csv'
        s.to_csv(n)
        m += 1
        qq.append(i)
    except:
        print('第{0}个数据保存失败，代码是{1}'.format(m,i))
        m += 1
        pass
# Out:
# 正在保存第1个数据，代码是600000
# 正在保存第2个数据，代码是600008
# 正在保存第3个数据，代码是600009
# 正在保存第4个数据，代码是600010
# 正在保存第5个数据，代码是600011
# 正在保存第6个数据，代码是600015
# 正在保存第7个数据，代码是600016
# 正在保存第8个数据，代码是600018
# 正在保存第9个数据，代码是600019
# 正在保存第10个数据，代码是600021
# 正在保存第11个数据，代码是600023
# 正在保存第12个数据，代码是600028
# 正在保存第13个数据，代码是600029
# 正在保存第14个数据，代码是600030
# 正在保存第15个数据，代码是600031
# 正在保存第16个数据，代码是600036
# 正在保存第17个数据，代码是600038
# 正在保存第18个数据，代码是600048
# 正在保存第19个数据，代码是600050
# 正在保存第20个数据，代码是600061
# 正在保存第21个数据，代码是600066
# 正在保存第22个数据，代码是600068
# 正在保存第23个数据，代码是600074
# 正在保存第24个数据，代码是600085
# 正在保存第25个数据，代码是600089
# 正在保存第26个数据，代码是600100
# 正在保存第27个数据，代码是600104
# 正在保存第28个数据，代码是600109
# 正在保存第29个数据，代码是600111
# 正在保存第30个数据，代码是600115
# 正在保存第31个数据，代码是600118
# 正在保存第32个数据，代码是600153
# 正在保存第33个数据，代码是600157
# 正在保存第34个数据，代码是600170
# 正在保存第35个数据，代码是600177
# 正在保存第36个数据，代码是600188
# 正在保存第37个数据，代码是600196
# 正在保存第38个数据，代码是600208
# 正在保存第39个数据，代码是600219
# 正在保存第40个数据，代码是600221
# 正在保存第41个数据，代码是600233
# 正在保存第42个数据，代码是600271
# 正在保存第43个数据，代码是600276
# ...

# %%
temp = pd.DataFrame(columns = ['code','date','ma5','volume','v_ma5','turnover','p_change']) #创建用于储存的空数据框
#temp.insert(0,'code',qq)
for file in qq:
    file = str(file)
    excel_path = '/Users/liuhuanshuo/Desktop/zuoye/lianghua/策略/' + file + '.csv'
    df = pd.read_csv(excel_path) 
    df_one = df.loc[:,['code','date','ma5','volume','v_ma5','turnover','p_change']]  #切片 提取指定列
    a = df_one[(df_one.date == '2016-04-01')] #选择特定行
    temp = temp.append(a,ignore_index=True) #将刚刚选取的行添加到数据框中，可以帮助忽略index，自动递增
temp
# Out:
#        code        date      ma5      volume       v_ma5  turnover  p_change
# 0    600000  2016-04-01   17.780   357905.41   277575.29      0.19      1.39
# 1    600008  2016-04-01    8.392   410178.75   497203.17      1.70      1.77
# 2    600009  2016-04-01   29.620    35015.26    70430.00      0.32     -0.73
# 3    600010  2016-04-01    2.964  1013889.94   662531.09      0.64      1.69
# 4    600011  2016-04-01    7.936   157125.20   173151.69      0.15      0.63
# 5    600015  2016-04-01   10.126   341792.94   250886.24      0.44      0.59
# 6    600016  2016-04-01    9.064   941101.62   670562.64      0.32      1.43
# 7    600018  2016-04-01    5.236   997576.44   653753.35      0.44     -2.16
# 8    600019  2016-04-01    5.234   541091.81   398636.47      0.33      1.52
# 9    600021  2016-04-01   11.578   111277.24   142437.23      0.52     -0.60
# 10   600023  2016-04-01    5.512   335836.75   343105.92      1.12     -0.18
# ...

# %%
data = temp.loc[:,['ma5','volume','v_ma5','turnover','p_change']]

# %%
k = 5 #聚类的类别

iteration = 500 #聚类最大循环次数

data = data

data_zs = 1.0*(data - data.mean())/data.std() #数据标准化

from sklearn.cluster import KMeans

model = KMeans(n_clusters = k, n_jobs = 4, max_iter = iteration) #分为k类, 并发数4

model.fit(data_zs) #开始聚类

#简单打印结果

r1 = pd.Series(model.labels_).value_counts() #统计各个类别的数目

r2 = pd.DataFrame(model.cluster_centers_) #找出聚类中心

r = pd.concat([r2, r1], axis = 1) #横向连接(0是纵向), 得到聚类中心对应的类别下的数目

r.columns = list(data.columns) + [u'类别数目'] #重命名表头

print(r)

#详细输出原始数据及其类别

r = pd.concat([data, pd.Series(model.labels_, index = data.index)], axis = 1)  #详细输出每个样本对应的类别

r.columns = list(data.columns) + [u'聚类类别'] #重命名表头

r
# Out:
#         ma5    volume     v_ma5  turnover  p_change  类别数目
# 0  0.046741 -0.519264 -0.518740 -0.245134 -0.218831   161
# 1 -0.490608  0.656566  0.795422 -0.114162  0.016718    64
# 2 -0.397699  1.730893  0.779366  2.018064  3.113155    11
# 3  3.585492 -0.512128 -0.466531  2.787178  0.056309     9
# 4 -0.502645  3.393830  3.529497 -0.063792 -0.073704     8
#          ma5      volume       v_ma5  turnover  p_change  聚类类别
# 0     17.780   357905.41   277575.29      0.19      1.39     0
# 1      8.392   410178.75   497203.17      1.70      1.77     1
# 2     29.620    35015.26    70430.00      0.32     -0.73     0
# 3      2.964  1013889.94   662531.09      0.64      1.69     1
# 4      7.936   157125.20   173151.69      0.15      0.63     0
# 5     10.126   341792.94   250886.24      0.44      0.59     0
# 6      9.064   941101.62   670562.64      0.32      1.43     1
# 7      5.236   997576.44   653753.35      0.44     -2.16     1
# ...

# %%
from sklearn.manifold import TSNE
tsne = TSNE()
tsne.fit_transform(data_zs) #进行数据降维
tsne = pd.DataFrame(tsne.embedding_, index = data_zs.index) #转换数据格式
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False #用来正常显示负号
#不同类别用不同颜色和样式绘图
d = tsne[r[u'聚类类别'] == 0]
plt.plot(d[0], d[1], 'r.')
d = tsne[r[u'聚类类别'] == 1]
plt.plot(d[0], d[1], 'go')
d = tsne[r[u'聚类类别'] == 2]
plt.plot(d[0], d[1], 'b*')
d = tsne[r[u'聚类类别'] == 3]
plt.plot(d[0], d[1], 'g+')
d = tsne[r[u'聚类类别'] == 4]
plt.plot(d[0], d[1], 'y+')
'''d = tsne[r[u'聚类类别'] == 5]
plt.plot(d[0], d[1], 'b+')'''
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ll = r.loc[:,'聚类类别']

# %%
temp.insert(7,'聚类类别',ll)
temp
# Out:
#        code        date      ma5      volume       v_ma5  turnover  p_change  \
# 0    600000  2016-04-01   17.780   357905.41   277575.29      0.19      1.39
# 1    600008  2016-04-01    8.392   410178.75   497203.17      1.70      1.77
# 2    600009  2016-04-01   29.620    35015.26    70430.00      0.32     -0.73
# 3    600010  2016-04-01    2.964  1013889.94   662531.09      0.64      1.69
# 4    600011  2016-04-01    7.936   157125.20   173151.69      0.15      0.63
# 5    600015  2016-04-01   10.126   341792.94   250886.24      0.44      0.59
# 6    600016  2016-04-01    9.064   941101.62   670562.64      0.32      1.43
# 7    600018  2016-04-01    5.236   997576.44   653753.35      0.44     -2.16
# 8    600019  2016-04-01    5.234   541091.81   398636.47      0.33      1.52
# 9    600021  2016-04-01   11.578   111277.24   142437.23      0.52     -0.60
# 10   600023  2016-04-01    5.512   335836.75   343105.92      1.12     -0.18
# ...

# %%
cc = temp[(temp.聚类类别 == 2)]

# %%
len(cc)
# Out:
# 11

# %%
j = '002601'
s = ts.get_hist_data('2601',start='2016-01-01',end='2017-01-01')
s

# %%
s
# Out:
#               code   open   high  close    low     volume  price_change  \
# date
# 2016-12-30  002601  12.62  12.69  12.66  12.58   32044.04          0.05
# 2016-12-29  002601  12.58  12.69  12.61  12.56   39637.30          0.00
# 2016-12-28  002601  12.74  12.83  12.61  12.59   57548.29         -0.17
# 2016-12-27  002601  12.51  12.99  12.78  12.51   93416.74          0.24
# 2016-12-26  002601  12.40  12.59  12.54  12.38   46583.78          0.12
# 2016-12-23  002601  12.66  12.78  12.42  12.41   66368.73         -0.28
# 2016-12-22  002601  12.80  12.83  12.70  12.70   65896.65         -0.15
# 2016-12-21  002601  12.91  12.94  12.85  12.82   54648.46          0.00
# 2016-12-20  002601  12.91  12.95  12.85  12.71   68557.55         -0.09
# 2016-12-19  002601  13.01  13.08  12.94  12.90   48077.39         -0.14
# 2016-12-16  002601  13.10  13.33  13.08  12.91   79207.50         -0.07
# 2016-12-15  002601  12.63  13.50  13.15  12.63  114954.43          0.34
# ...
